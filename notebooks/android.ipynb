# %% [markdown]
# # Root Cause Search in Android Dataset
#
# This Notebook presents an example execution of the algorithm. The test is performed using 10 reference errors within a segment of an Android log dataset comprising 10 million lines. Execution was carried out on a MacBook Air M1 equipped with 16 GB of RAM. The purpose of this notebook is to showcase the functionality and provide insights into the code's behavior with the specified dataset and hardware conditions.

# %%
import sys
sys.path.append("../root_cause")
from search import RootCauseSearch
from settings import SearchStrategy
from settings import SearchSettings
from output import DisplayNotebookOutput

# %% [markdown]
# # General Settings

# %%
search_strategy = {
    'intersection_occurrences_col': 'content',
    'intersection_col': 'service_template_id',
    'hidden_occurrences_col': 'service_template_id',
    'uniqueness_col': 'content',
    'max_noise': 1,
    'window_seconds': 2
}

general_settings = {
    'dataset_name': 'ba',
    'storage_dir': '../storage',
    'source_csv_file': '../storage/ba.source.csv',
    'drain_config_file': '../drain3.ini',
    'service_filter': ['PowerManagerService', 'HicomNfTimerManager', 'HwAmbientLuxFilterAlgo', 'chatty'],
    'content_filter': ['ApiCount', r'^Date: '],
    'duplicate_filter_col': 'service_template_id',
    'parallel_processing': True,
    'output': DisplayNotebookOutput()
}

# %% [markdown]
# # Search

# %%
search_strategies = [SearchStrategy(**search_strategy)]
search_settings = SearchSettings(strategies=search_strategies, **general_settings)

root_cause = RootCauseSearch(search_settings)
# Out:
# Loading dataset from CSV file and preparing it:
# ↻ Preparing dataset for template clustering ...
# ↻ Creating template clusters ...
# ↻ Assigning the templates to their log messages ...
# ✓ Dataset loaded and prepared.

# %% [markdown]
# ## Error 1

# %%
rc1 = root_cause.search(542657)
# Out:
# Trying search strategy "content|service_template_id|service_template_id|content|1":
# ℹ 2 error occurrences found. They are used to create a intersection of all time windows before the error.
# ℹ 109 values in intersection of time windows found.
# ℹ 25 error occurrences found. They are used to mark the time windows that are skipped in the uniqueness check for root cause candidates.
# ✓ 22 lines added to root cause.
#
# Results:
#
# Line: 538728
# Timestamp: 2020-12-02 14:31:45.708000
# Service: hievent_jni
# Template: Write to dev len:<:NUM:>
# Content: Write to dev len:283
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 539398
# Timestamp: 2020-12-02 14:31:45.797000
# Service: nStackXDMsg
# Template: <:*:> <:*:> <:*:> <:*:> = <:NUM:>, <:*:> = <:NUM:>
# Content: StartDMsgMainThread:[1303] :[START THREAD]pthread_create tid = 520342080848, epollfd = 231
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 540420
# Timestamp: 2020-12-02 14:31:45.912000
# Service: nStackXDMsg
# Template: <:*:> <:*:> <:*:> <:*:> <:*:> = <:NUM:>, <:*:> = <:NUM:>
# Content: NSTACKX_DMsgClose:[1625] :[CLOSE SESSION]type 1, tid = 520342080848, epollfd = 231
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 541696
# Timestamp: 2020-12-02 14:31:46.361000
# Service: WificondControl
# Template: Noise: <:NUM:>, Snr: <:NUM:>, Chload: <:NUM:>, rssi: <:NUM:>, txBitrate: <:NUM:>, rxBitrate: <:NUM:>, frequency: <:NUM:>, UlDelay: <:NUM:>, currentTxBytes: <:*:> currentTxPackets: <:NUM:>, currentTxFailed: <:NUM:>, currentRxBytes: <:*:> currentRxPackets: <:NUM:>
# Content: Noise: -100, Snr: 32, Chload: 190, rssi: -37, txBitrate: 117, rxBitrate: 390, frequency: 5745, UlDelay: 0, currentTxBytes: 454580037, currentTxPackets: 362670, currentTxFailed: 0, currentRxBytes: 72692252, currentRxPackets: 154489
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 542377
# Timestamp: 2020-12-02 14:31:46.822000
# Service: HiSight-RTSP-Net
# Template: [ NetSessionImpl.java: <:*:> <:*:> error, socket closed, SocketException: java.net.SocketException: <:*:> <:*:>
# Content: [ NetSessionImpl.java: 293]rtsp:Receive data error, socket closed, SocketException: java.net.SocketException: Connection reset
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 542381
# Timestamp: 2020-12-02 14:31:46.825000
# Service: HiTraceC
# Template: <:*:> (CS)msg send what=<:NUM:>, arg1=<:NUM:>, arg2=<:NUM:>, sendUid=<:NUM:>, workSrcUid=<:NUM:>, when=<:NUM:>
# Content: <DEFAULT,CS,[248cb431c6ed840,2a18bb3,0]> (CS)msg send what=14, arg1=0, arg2=0, sendUid=-1, workSrcUid=-1, when=0
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 542383
# Timestamp: 2020-12-02 14:31:46.825000
# Service: HiTraceC
# Template: <:*:> (SR) begin handle msg what=<:NUM:>, arg1=<:NUM:>, arg2=<:NUM:>, sendUid=<:NUM:>, workSrcUid=<:NUM:>, <:*:>
# Content: <DEFAULT,SR,[248cb431c6ed840,2a18bb3,0]> (SR) begin handle msg what=14, arg1=0, arg2=0, sendUid=-1, workSrcUid=-1, when=4187841
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 542395
# Timestamp: 2020-12-02 14:31:46.826000
# Service: HiSight-RTSP-Encap
# Template: <:*:> <:NUM:>
# Content: CSeq: 18
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 542415
# Timestamp: 2020-12-02 14:31:46.836000
# Service: HiView.HiEvent
# Template: Flatten done:<:NUM:>
# Content: Flatten done:950005005
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|1
#
# Line: 542425
# Timestamp: 2020-12-02 14:31:46.844000
# Service: HiSight-M-SenderTCP
# Template: [ <:*:> <:NUM:>]ERROR : <:*:> <:*:> : <:*:> <:*:> <:*:>
# Content: [ HiSightTcpSender.java: 167]ERROR : sendData IOException : java.net.SocketException: Broken pipe
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 542430
# Timestamp: 2020-12-02 14:31:46.845000
# Service: HiSight-M-MediaManager
# Template: [ <:*:> <:*:> <:*:> = <:NUM:>
# Content: [ MediaManager.java: 258]onServerSendError trackId = 0
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 542431
# Timestamp: 2020-12-02 14:31:46.845000
# Service: HiSight-HiSightSession
# Template: [ HiSightSession.java: <:*:> <:*:>
# Content: [ HiSightSession.java: 1670]MediaManager onDataError
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 542442
# Timestamp: 2020-12-02 14:31:46.848000
# Service: HiTraceC
# Template: <:*:> (SS)finish handle msg what=<:NUM:>, arg1=<:NUM:>, arg2=<:NUM:>, sendUid=<:NUM:>, workSrcUid=<:NUM:>, <:*:>
# Content: <DEFAULT,SS,[248cb431c6ed840,2a18bb3,0]> (SS)finish handle msg what=14, arg1=0, arg2=0, sendUid=-1, workSrcUid=-1, when=4187841
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 542482
# Timestamp: 2020-12-02 14:31:46.859000
# Service: DisplayManagerService
# Template: Display device <:*:> <:*:> <:*:> <:NUM:> x <:NUM:>, modeId <:NUM:>, defaultModeId <:NUM:>, supportedModes [{id=<:NUM:>, width=<:NUM:>, height=<:NUM:>, fps=<:NUM:>}], colorMode <:NUM:>, supportedColorModes [<:NUM:>], HdrCapabilities null, density <:NUM:>, <:NUM:> x <:NUM:> dpi, appVsyncOff <:NUM:>, presDeadline <:DATE:>, touch NONE, rotation <:NUM:>, type VIRTUAL, state ON, owner com.huawei.android.airsharing (uid <:NUM:>), FLAG_PRESENTATION}
# Content: Display device removed: DisplayDeviceInfo{"HiSightPCDisplay": uniqueId="virtual:com.huawei.android.airsharing,1000,HiSightPCDisplay,0", 1152 x 2376, modeId 22, defaultModeId 22, supportedModes [{id=22, width=1152, height=2376, fps=60.0}], colorMode 0, supportedColorModes [0], HdrCapabilities null, density 480, 480.0 x 480.0 dpi, appVsyncOff 0, presDeadline 16666666, touch NONE, rotation 0, type VIRTUAL, state ON, owner com.huawei.android.airsharing (uid 1000), FLAG_PRESENTATION}
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 542506
# Timestamp: 2020-12-02 14:31:46.864000
# Service: HwActivityStackSupervisorEx
# Template: <:*:> <:*:> = <:NUM:>
# Content: handleVrDisplayRemoved displayId = 20
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|1
#
# Line: 542507
# Timestamp: 2020-12-02 14:31:46.864000
# Service: HwActivityStackSupervisorEx
# Template: <:*:> <:*:> mode <:*:> <:NUM:>
# Content: handleVrDisplayRemoved other mode displayId: 20
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|1
#
# Line: 542539
# Timestamp: 2020-12-02 14:31:46.866000
# Service: HwMultiDisplayManager
# Template: <:*:> <:NUM:>
# Content: onDisplayRemoved: 20
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|1
#
# Line: 542577
# Timestamp: 2020-12-02 14:31:46.876000
# Service: InputDispatcher
# Template: channel <:*:> (server)' ~ Consumer closed input channel or an error occurred. events=<:HEX:>
# Content: channel 'PointerEventDispatcher20 (server)' ~ Consumer closed input channel or an error occurred.  events=0x9
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|1
#
# Line: 542578
# Timestamp: 2020-12-02 14:31:46.876000
# Service: InputDispatcher
# Template: <:*:> (server)
# Content: unregisterInputMonitor:PointerEventDispatcher20 (server)
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|1
#
# Line: 542584
# Timestamp: 2020-12-02 14:31:46.881000
# Service: HANDoff-MultiDisplayShareScreenManager
# Template: <:*:> displayId=<:NUM:>
# Content: handleDisplayRemove, displayId=20
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 542605
# Timestamp: 2020-12-02 14:31:46.895000
# Service: VENC
# Template: [ComponentDeInit]:[<:NUM:>] etbCountTry:<:NUM:>, etbCountOk:<:NUM:>, ebdCountTry:<:NUM:>, ebdCountOk:<:NUM:>, ftbCountTry:<:NUM:>, ftbCountOk:<:NUM:>, fbdCountTry:<:NUM:>, fbdCountOk:<:NUM:>
# Content: [ComponentDeInit]:[8615] etbCountTry:23331, etbCountOk:23331, ebdCountTry:23331, ebdCountOk:23331, ftbCountTry:23347, ftbCountOk:23347, fbdCountTry:23347, fbdCountOk:23347
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 542631
# Timestamp: 2020-12-02 14:31:46.904000
# Service: HwActivityTaskManagerServiceEx
# Template: unregisterHwActivityNotifier notifier: <:*:> callingUid: <:NUM:> callingPid: <:NUM:>
# Content: unregisterHwActivityNotifier notifier: android.app.IHwActivityNotifier$Stub$Proxy@26d06ff, callingUid: 1000 callingPid: 12671
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 542657
# Timestamp: 2020-12-02 14:31:46.907000
# Service: NcDftImpl
# Template: connectivityDftReport scenario: castplus-disconnect eventId: <:NUM:> eventMsg: <:*:> disconnect","ErrCode":"<:NUM:>","SubErrCode":"<:NUM:>"}
# Content: connectivityDftReport scenario: castplus-disconnect eventId: 0 eventMsg: {"Scenario":"phone-pc","ErrType":"abnormal disconnect","ErrCode":"0","SubErrCode":"1"}

# %% [markdown]
# ✅ The root cause can be derived from the returned result: A sudden disconnection to an external device (presumably VR technology) with a screen and input capability led to a failed TCP transmission of media content.
#
# ## Error 2

# %%
rc2 = root_cause.search(546260)
# Out:
# Reloading dataset from CSV file:
# ✓ Dataset loaded.
# Trying search strategy "content|service_template_id|service_template_id|content|1":
# ℹ 8 error occurrences found. They are used to create a intersection of all time windows before the error.
# ℹ 3 values in intersection of time windows found.
# ℹ 94 error occurrences found. They are used to mark the time windows that are skipped in the uniqueness check for root cause candidates.
# ✓ 1 lines added to root cause.
#
# Results:
#
# Line: 546259
# Timestamp: 2020-12-02 14:31:48.407000
# Service: wpa_supplicant
# Template: Notifying <:*:> <:*:> to hidl control: <:NUM:>
# Content: Notifying disconnect reason to hidl control: -3
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|1
#
# Line: 546260
# Timestamp: 2020-12-02 14:31:48.407000
# Service: wpa_supplicant
# Template: <:*:> Disconnect event - remove keys
# Content: p2p-p2p0-1: Disconnect event - remove keys

# %% [markdown]
# ❌ The root cause can not be derived from the returned result.
#
# ## Error 3

# %%
rc3 = root_cause.search(596489)
# Out:
# Reloading dataset from CSV file:
# ✓ Dataset loaded.
# Trying search strategy "content|service_template_id|service_template_id|content|1":
# ℹ 81 error occurrences found. They are used to create a intersection of all time windows before the error.
# ℹ 2 values in intersection of time windows found.
# ℹ 140 error occurrences found. They are used to mark the time windows that are skipped in the uniqueness check for root cause candidates.
# ✓ 1 lines added to root cause.
#
# Results:
#
# Line: 596488
# Timestamp: 2020-12-02 14:32:29.178000
# Service: wpa_supplicant
# Template: nl80211: Drv Event <:NUM:> <:*:> received for <:*:>
# Content: nl80211: Drv Event 48 (NL80211_CMD_DISCONNECT) received for p2p-p2p0-2
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 596489
# Timestamp: 2020-12-02 14:32:29.178000
# Service: wpa_supplicant
# Template: nl80211: <:*:> event
# Content: nl80211: Disconnect event

# %% [markdown]
# ✅ The root cause can be derived from the returned result: The Wi-Fi connection to a peer-to-peer interface of the mobile phone cannot be established. A brief Google search for the error code "NL80211_CMD_DISCONNECT" also indicates that the reason is a lack of support for 5 GHz Wi-Fi networks.
#
# ## Error 4

# %%
rc4 = root_cause.search(596536)
# Out:
# Reloading dataset from CSV file:
# ✓ Dataset loaded.
# Trying search strategy "content|service_template_id|service_template_id|content|1":
# ℹ 8 error occurrences found. They are used to create a intersection of all time windows before the error.
# ℹ 9 values in intersection of time windows found.
# ℹ 94 error occurrences found. They are used to mark the time windows that are skipped in the uniqueness check for root cause candidates.
# ✓ 5 lines added to root cause.
#
# Results:
#
# Line: 596493
# Timestamp: 2020-12-02 14:32:29.178000
# Service: wpa_supplicant
# Template: P2P: wpas_p2p_group_delete, interface name:p2p-p2p0-<:NUM:>.
# Content: P2P: wpas_p2p_group_delete, interface name:p2p-p2p0-2.
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 596496
# Timestamp: 2020-12-02 14:32:29.178000
# Service: wpa_supplicant
# Template: <:*:> Request to deauthenticate - <:*:> <:*:> reason=<:NUM:> <:*:>
# Content: p2p-p2p0-2: Request to deauthenticate - bssid=d6:**:**:**:a0:fb pending_bssid=00:**:**:**:00:00 reason=3 state=COMPLETED
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 596530
# Timestamp: 2020-12-02 14:32:29.182000
# Service: wpa_supplicant
# Template: <:*:> CTRL-EVENT-DISCONNECTED <:*:> reason=<:NUM:> locally_generated=<:NUM:>
# Content: p2p-p2p0-2: CTRL-EVENT-DISCONNECTED bssid=d6:**:**:**:a0:fb reason=3 locally_generated=1
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 596532
# Timestamp: 2020-12-02 14:32:29.182000
# Service: wpa_supplicant
# Template: <:*:> Ignore connection failure indication since interface has been put into disconnected state
# Content: p2p-p2p0-2: Ignore connection failure indication since interface has been put into disconnected state
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 596534
# Timestamp: 2020-12-02 14:32:29.182000
# Service: wpa_supplicant
# Template: Notifying <:*:> <:*:> to hidl control: <:NUM:>
# Content: Notifying disconnect reason to hidl control: -3
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|1
#
# Line: 596536
# Timestamp: 2020-12-02 14:32:29.182000
# Service: wpa_supplicant
# Template: <:*:> Disconnect event - remove keys
# Content: p2p-p2p0-2: Disconnect event - remove keys

# %% [markdown]
# ✅ The root cause can be derived from the returned result: The virtual peer-to-peer Wi-Fi interface was deleted, leading to the deauthentication of all connected devices.
#
# ## Error 5

# %%
rc5 = root_cause.search(620427)
# Out:
# Reloading dataset from CSV file:
# ✓ Dataset loaded.
# Trying search strategy "content|service_template_id|service_template_id|content|1":
# ℹ 5 error occurrences found. They are used to create a intersection of all time windows before the error.
# ℹ 92 values in intersection of time windows found.
# ℹ 25 error occurrences found. They are used to mark the time windows that are skipped in the uniqueness check for root cause candidates.
# ✓ 12 lines added to root cause.
#
# Results:
#
# Line: 620180
# Timestamp: 2020-12-02 14:32:45.554000
# Service: HiSight-RTSP-Net
# Template: [ NetSessionImpl.java: <:*:> <:*:> error, socket closed, SocketException: java.net.SocketException: <:*:> <:*:>
# Content: [ NetSessionImpl.java: 293]rtsp:Receive data error, socket closed, SocketException: java.net.SocketException: Connection reset
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 620181
# Timestamp: 2020-12-02 14:32:45.554000
# Service: HiSight-RTSP-Net
# Template: [ NetSessionImpl.java: <:NUM:>]rtsp:IOException: read is0 expect is87
# Content: [ NetSessionImpl.java: 2331]rtsp:IOException: read is0 expect is87
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 620292
# Timestamp: 2020-12-02 14:32:45.573000
# Service: DisplayManagerService
# Template: Display device <:*:> <:*:> <:*:> <:NUM:> x <:NUM:>, modeId <:NUM:>, defaultModeId <:NUM:>, supportedModes [{id=<:NUM:>, width=<:NUM:>, height=<:NUM:>, fps=<:NUM:>}], colorMode <:NUM:>, supportedColorModes [<:NUM:>], HdrCapabilities null, density <:NUM:>, <:NUM:> x <:NUM:> dpi, appVsyncOff <:NUM:>, presDeadline <:DATE:>, touch NONE, rotation <:NUM:>, type VIRTUAL, state ON, owner com.huawei.android.airsharing (uid <:NUM:>), FLAG_PRESENTATION}
# Content: Display device removed: DisplayDeviceInfo{"HiSightPCDisplay": uniqueId="virtual:com.huawei.android.airsharing,1000,HiSightPCDisplay,0", 1152 x 2376, modeId 24, defaultModeId 24, supportedModes [{id=24, width=1152, height=2376, fps=60.0}], colorMode 0, supportedColorModes [0], HdrCapabilities null, density 480, 480.0 x 480.0 dpi, appVsyncOff 0, presDeadline 16666666, touch NONE, rotation 0, type VIRTUAL, state ON, owner com.huawei.android.airsharing (uid 1000), FLAG_PRESENTATION}
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 620310
# Timestamp: 2020-12-02 14:32:45.574000
# Service: HwActivityStackSupervisorEx
# Template: <:*:> <:*:> = <:NUM:>
# Content: handleVrDisplayRemoved displayId = 22
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 620318
# Timestamp: 2020-12-02 14:32:45.576000
# Service: HwActivityStackSupervisorEx
# Template: <:*:> <:*:> mode <:*:> <:NUM:>
# Content: handleVrDisplayRemoved other mode displayId: 22
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 620320
# Timestamp: 2020-12-02 14:32:45.576000
# Service: HwMultiDisplayManager
# Template: <:*:> <:NUM:>
# Content: onDisplayRemoved: 22
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 620322
# Timestamp: 2020-12-02 14:32:45.576000
# Service: HwPCUtils#HwWindowsCastManager
# Template: <:*:> <:NUM:>
# Content: onDisplayRemoved 22
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 620364
# Timestamp: 2020-12-02 14:32:45.587000
# Service: InputDispatcher
# Template: channel <:*:> (server)' ~ Consumer closed input channel or an error occurred. events=<:HEX:>
# Content: channel 'PointerEventDispatcher22 (server)' ~ Consumer closed input channel or an error occurred.  events=0x9
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 620365
# Timestamp: 2020-12-02 14:32:45.587000
# Service: InputDispatcher
# Template: <:*:> (server)
# Content: unregisterInputMonitor:PointerEventDispatcher22 (server)
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 620382
# Timestamp: 2020-12-02 14:32:45.595000
# Service: VENC
# Template: [ComponentDeInit]:[<:NUM:>] etbCountTry:<:NUM:>, etbCountOk:<:NUM:>, ebdCountTry:<:NUM:>, ebdCountOk:<:NUM:>, ftbCountTry:<:NUM:>, ftbCountOk:<:NUM:>, fbdCountTry:<:NUM:>, fbdCountOk:<:NUM:>
# Content: [ComponentDeInit]:[8615] etbCountTry:165, etbCountOk:165, ebdCountTry:165, ebdCountOk:165, ftbCountTry:181, ftbCountOk:181, fbdCountTry:181, fbdCountOk:181
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 620399
# Timestamp: 2020-12-02 14:32:45.601000
# Service: HiSight-M-SenderTCP
# Template: [ <:*:> <:*:> in
# Content: [ HiSightTcpSender.java: 197]stopSend in
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 620403
# Timestamp: 2020-12-02 14:32:45.603000
# Service: HwActivityTaskManagerServiceEx
# Template: unregisterHwActivityNotifier notifier: <:*:> callingUid: <:NUM:> callingPid: <:NUM:>
# Content: unregisterHwActivityNotifier notifier: android.app.IHwActivityNotifier$Stub$Proxy@2748b35, callingUid: 1000 callingPid: 12671
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 620427
# Timestamp: 2020-12-02 14:32:45.606000
# Service: NcDftImpl
# Template: connectivityDftReport scenario: castplus-disconnect eventId: <:NUM:> eventMsg: <:*:> disconnect","ErrCode":"<:NUM:>","SubErrCode":"<:NUM:>"}
# Content: connectivityDftReport scenario: castplus-disconnect eventId: 0 eventMsg: {"Scenario":"phone-pc","ErrType":"abnormal disconnect","ErrCode":"4","SubErrCode":"5"}

# %% [markdown]
# ✅ The root cause can be derived from the returned result: A sudden disconnection to an external device (presumably VR technology) with a screen and input capability led to a failed TCP transmission of media content.
#
# ## Error 6

# %%
rc6 = root_cause.search(623042)
# Out:
# Reloading dataset from CSV file:
# ✓ Dataset loaded.
# Trying search strategy "content|service_template_id|service_template_id|content|1":
# ℹ 5 error occurrences found. They are used to create a intersection of all time windows before the error.
# ℹ 73 values in intersection of time windows found.
# ℹ 94 error occurrences found. They are used to mark the time windows that are skipped in the uniqueness check for root cause candidates.
# ✓ 7 lines added to root cause.
#
# Results:
#
# Line: 616241
# Timestamp: 2020-12-02 14:32:44.572000
# Service: DMSDP
# Template: <:*:> <:*:> mDeviceType=<:NUM:>, <:*:> <:*:> mBtName='', <:*:> <:*:> mBusinessId=<:NUM:>', mChannelType=<:NUM:>}
# Content: DMSDPDeviceManager:checkRemainEventReport device:InnerDMSDPDevice{mDeviceId='CD****35', mDeviceType=7, mDeviceName='', mBluetoothMac='', mBtName='', mLocalIp='19****.1', mRemoteIp='19****13', mBusinessId=2', mChannelType=0}
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 620310
# Timestamp: 2020-12-02 14:32:45.574000
# Service: HwActivityStackSupervisorEx
# Template: <:*:> <:*:> = <:NUM:>
# Content: handleVrDisplayRemoved displayId = 22
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|1
#
# Line: 620318
# Timestamp: 2020-12-02 14:32:45.576000
# Service: HwActivityStackSupervisorEx
# Template: <:*:> <:*:> mode <:*:> <:NUM:>
# Content: handleVrDisplayRemoved other mode displayId: 22
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|1
#
# Line: 620320
# Timestamp: 2020-12-02 14:32:45.576000
# Service: HwMultiDisplayManager
# Template: <:*:> <:NUM:>
# Content: onDisplayRemoved: 22
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|1
#
# Line: 620382
# Timestamp: 2020-12-02 14:32:45.595000
# Service: VENC
# Template: [ComponentDeInit]:[<:NUM:>] etbCountTry:<:NUM:>, etbCountOk:<:NUM:>, ebdCountTry:<:NUM:>, ebdCountOk:<:NUM:>, ftbCountTry:<:NUM:>, ftbCountOk:<:NUM:>, fbdCountTry:<:NUM:>, fbdCountOk:<:NUM:>
# Content: [ComponentDeInit]:[8615] etbCountTry:165, etbCountOk:165, ebdCountTry:165, ebdCountOk:165, ftbCountTry:181, ftbCountOk:181, fbdCountTry:181, fbdCountOk:181
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 623013
# Timestamp: 2020-12-02 14:32:45.989000
# Service: WifiP2pService
# Template: <:*:> what=<:NUM:> arg1=<:NUM:> arg2=<:NUM:>
# Content: GroupCreatedStatewhen=4247006 what=141275 arg1=0 arg2=8
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 623041
# Timestamp: 2020-12-02 14:32:45.994000
# Service: wpa_supplicant
# Template: Notifying <:*:> <:*:> to hidl control: <:NUM:>
# Content: Notifying disconnect reason to hidl control: -3
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|1
#
# Line: 623042
# Timestamp: 2020-12-02 14:32:45.994000
# Service: wpa_supplicant
# Template: <:*:> Disconnect event - remove keys
# Content: p2p-p2p0-3: Disconnect event - remove keys

# %% [markdown]
# ❌ The root cause can not be derived from the returned result.
#
# ## Error 7

# %%
rc7 = root_cause.search(643184)
# Out:
# Reloading dataset from CSV file:
# ✓ Dataset loaded.
# Trying search strategy "content|service_template_id|service_template_id|content|1":
# ℹ 81 error occurrences found. They are used to create a intersection of all time windows before the error.
# ℹ 2 values in intersection of time windows found.
# ℹ 140 error occurrences found. They are used to mark the time windows that are skipped in the uniqueness check for root cause candidates.
# ✓ 1 lines added to root cause.
#
# Results:
#
# Line: 643183
# Timestamp: 2020-12-02 14:33:00.639000
# Service: wpa_supplicant
# Template: nl80211: Drv Event <:NUM:> <:*:> received for <:*:>
# Content: nl80211: Drv Event 48 (NL80211_CMD_DISCONNECT) received for p2p-p2p0-4
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 643184
# Timestamp: 2020-12-02 14:33:00.639000
# Service: wpa_supplicant
# Template: nl80211: <:*:> event
# Content: nl80211: Disconnect event

# %% [markdown]
# ✅ The root cause can be derived from the returned result: The Wi-Fi connection to a peer-to-peer interface of the mobile phone cannot be established. A brief Google search for the error code "NL80211_CMD_DISCONNECT" also indicates that the reason is a lack of support for 5 GHz Wi-Fi networks.
#
# ## Error 8

# %%
rc8 = root_cause.search(643203)
# Out:
# Reloading dataset from CSV file:
# ✓ Dataset loaded.
# Trying search strategy "content|service_template_id|service_template_id|content|1":
# ℹ 4 error occurrences found. They are used to create a intersection of all time windows before the error.
# ℹ 15 values in intersection of time windows found.
# ℹ 94 error occurrences found. They are used to mark the time windows that are skipped in the uniqueness check for root cause candidates.
# ✓ 8 lines added to root cause.
#
# Results:
#
# Line: 643188
# Timestamp: 2020-12-02 14:33:00.640000
# Service: wpa_supplicant
# Template: P2P: wpas_p2p_group_delete, interface name:p2p-p2p0-<:NUM:>.
# Content: P2P: wpas_p2p_group_delete, interface name:p2p-p2p0-4.
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 643190
# Timestamp: 2020-12-02 14:33:00.640000
# Service: wpa_supplicant
# Template: <:*:> Request to deauthenticate - <:*:> <:*:> reason=<:NUM:> <:*:>
# Content: p2p-p2p0-4: Request to deauthenticate - bssid=32:**:**:**:36:68 pending_bssid=00:**:**:**:00:00 reason=3 state=COMPLETED
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 643192
# Timestamp: 2020-12-02 14:33:00.640000
# Service: WifiP2pService
# Template: <:*:> what=<:NUM:> arg1=<:NUM:> arg2=<:NUM:>
# Content: GroupCreatedStatewhen=4261657 what=147486 arg1=0 arg2=0
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 643196
# Timestamp: 2020-12-02 14:33:00.641000
# Service: wpa_supplicant
# Template: <:*:> * reason <:NUM:> (locally generated)
# Content: p2p-p2p0-4:  * reason 3 (locally generated)
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 643198
# Timestamp: 2020-12-02 14:33:00.641000
# Service: wpa_supplicant
# Template: <:*:> CTRL-EVENT-DISCONNECTED <:*:> reason=<:NUM:> locally_generated=<:NUM:>
# Content: p2p-p2p0-4: CTRL-EVENT-DISCONNECTED bssid=32:**:**:**:36:68 reason=3 locally_generated=1
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 643199
# Timestamp: 2020-12-02 14:33:00.641000
# Service: wpa_supplicant
# Template: <:*:> Auto connect disabled: do not try to re-connect
# Content: p2p-p2p0-4: Auto connect disabled: do not try to re-connect
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 643200
# Timestamp: 2020-12-02 14:33:00.641000
# Service: wpa_supplicant
# Template: <:*:> Ignore connection failure indication since interface has been put into disconnected state
# Content: p2p-p2p0-4: Ignore connection failure indication since interface has been put into disconnected state
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 643202
# Timestamp: 2020-12-02 14:33:00.641000
# Service: wpa_supplicant
# Template: Notifying <:*:> <:*:> to hidl control: <:NUM:>
# Content: Notifying disconnect reason to hidl control: -3
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|1
#
# Line: 643203
# Timestamp: 2020-12-02 14:33:00.641000
# Service: wpa_supplicant
# Template: <:*:> Disconnect event - remove keys
# Content: p2p-p2p0-4: Disconnect event - remove keys

# %% [markdown]
# ✅ The root cause can be derived from the returned result: The virtual peer-to-peer Wi-Fi interface was deleted, leading to the deauthentication of all connected devices.
#
# ## Error 9

# %%
rc9 = root_cause.search(884269)
# Out:
# Reloading dataset from CSV file:
# ✓ Dataset loaded.
# Trying search strategy "content|service_template_id|service_template_id|content|1":
# ℹ 5 error occurrences found. They are used to create a intersection of all time windows before the error.
# ℹ 92 values in intersection of time windows found.
# ℹ 25 error occurrences found. They are used to mark the time windows that are skipped in the uniqueness check for root cause candidates.
# ✓ 13 lines added to root cause.
#
# Results:
#
# Line: 883749
# Timestamp: 2020-12-02 14:38:58.018000
# Service: HiSight-RTSP-Net
# Template: [ NetSessionImpl.java: <:*:> <:*:> error, socket closed, SocketException: java.net.SocketException: <:*:> <:*:>
# Content: [ NetSessionImpl.java: 293]rtsp:Receive data error, socket closed, SocketException: java.net.SocketException: Connection reset
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 883750
# Timestamp: 2020-12-02 14:38:58.018000
# Service: HiSight-RTSP-Net
# Template: [ NetSessionImpl.java: <:NUM:>]rtsp:IOException: read is0 expect is87
# Content: [ NetSessionImpl.java: 2331]rtsp:IOException: read is0 expect is87
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 883772
# Timestamp: 2020-12-02 14:38:58.024000
# Service: HiSight-RTSP-Encap
# Template: <:*:> <:NUM:>
# Content: CSeq: 11
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 883945
# Timestamp: 2020-12-02 14:38:58.078000
# Service: DisplayManagerService
# Template: Display device <:*:> <:*:> <:*:> <:NUM:> x <:NUM:>, modeId <:NUM:>, defaultModeId <:NUM:>, supportedModes [{id=<:NUM:>, width=<:NUM:>, height=<:NUM:>, fps=<:NUM:>}], colorMode <:NUM:>, supportedColorModes [<:NUM:>], HdrCapabilities null, density <:NUM:>, <:NUM:> x <:NUM:> dpi, appVsyncOff <:NUM:>, presDeadline <:DATE:>, touch NONE, rotation <:NUM:>, type VIRTUAL, state ON, owner com.huawei.android.airsharing (uid <:NUM:>), FLAG_PRESENTATION}
# Content: Display device removed: DisplayDeviceInfo{"HiSightPCDisplay": uniqueId="virtual:com.huawei.android.airsharing,1000,HiSightPCDisplay,0", 1152 x 2376, modeId 28, defaultModeId 28, supportedModes [{id=28, width=1152, height=2376, fps=60.0}], colorMode 0, supportedColorModes [0], HdrCapabilities null, density 480, 480.0 x 480.0 dpi, appVsyncOff 0, presDeadline 16666666, touch NONE, rotation 0, type VIRTUAL, state ON, owner com.huawei.android.airsharing (uid 1000), FLAG_PRESENTATION}
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 883979
# Timestamp: 2020-12-02 14:38:58.084000
# Service: HwActivityStackSupervisorEx
# Template: <:*:> <:*:> = <:NUM:>
# Content: handleVrDisplayRemoved displayId = 24
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 883993
# Timestamp: 2020-12-02 14:38:58.088000
# Service: HwActivityStackSupervisorEx
# Template: <:*:> <:*:> mode <:*:> <:NUM:>
# Content: handleVrDisplayRemoved other mode displayId: 24
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 883994
# Timestamp: 2020-12-02 14:38:58.089000
# Service: HwMultiDisplayManager
# Template: <:*:> <:NUM:>
# Content: onDisplayRemoved: 24
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 883995
# Timestamp: 2020-12-02 14:38:58.089000
# Service: HwPCUtils#HwWindowsCastManager
# Template: <:*:> <:NUM:>
# Content: onDisplayRemoved 24
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 884037
# Timestamp: 2020-12-02 14:38:58.115000
# Service: VENC
# Template: [ComponentDeInit]:[<:NUM:>] etbCountTry:<:NUM:>, etbCountOk:<:NUM:>, ebdCountTry:<:NUM:>, ebdCountOk:<:NUM:>, ftbCountTry:<:NUM:>, ftbCountOk:<:NUM:>, fbdCountTry:<:NUM:>, fbdCountOk:<:NUM:>
# Content: [ComponentDeInit]:[8615] etbCountTry:7794, etbCountOk:7794, ebdCountTry:7794, ebdCountOk:7794, ftbCountTry:7811, ftbCountOk:7811, fbdCountTry:7811, fbdCountOk:7811
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 884039
# Timestamp: 2020-12-02 14:38:58.115000
# Service: InputDispatcher
# Template: channel <:*:> (server)' ~ Consumer closed input channel or an error occurred. events=<:HEX:>
# Content: channel 'PointerEventDispatcher24 (server)' ~ Consumer closed input channel or an error occurred.  events=0x9
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 884041
# Timestamp: 2020-12-02 14:38:58.115000
# Service: InputDispatcher
# Template: <:*:> (server)
# Content: unregisterInputMonitor:PointerEventDispatcher24 (server)
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 884142
# Timestamp: 2020-12-02 14:38:58.126000
# Service: HiSight-M-SenderTCP
# Template: [ <:*:> <:*:> in
# Content: [ HiSightTcpSender.java: 197]stopSend in
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 884153
# Timestamp: 2020-12-02 14:38:58.128000
# Service: HwActivityTaskManagerServiceEx
# Template: unregisterHwActivityNotifier notifier: <:*:> callingUid: <:NUM:> callingPid: <:NUM:>
# Content: unregisterHwActivityNotifier notifier: android.app.IHwActivityNotifier$Stub$Proxy@2841377, callingUid: 1000 callingPid: 12671
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 884269
# Timestamp: 2020-12-02 14:38:58.134000
# Service: NcDftImpl
# Template: connectivityDftReport scenario: castplus-disconnect eventId: <:NUM:> eventMsg: <:*:> disconnect","ErrCode":"<:NUM:>","SubErrCode":"<:NUM:>"}
# Content: connectivityDftReport scenario: castplus-disconnect eventId: 0 eventMsg: {"Scenario":"phone-pc","ErrType":"abnormal disconnect","ErrCode":"4","SubErrCode":"5"}

# %% [markdown]
# ✅ The root cause can be derived from the returned result: A sudden disconnection to an external device (presumably VR technology) with a screen and input capability led to a failed TCP transmission of media content.
#
# ## Error 10

# %%
rc10 = root_cause.search(889546)
# Out:
# Reloading dataset from CSV file:
# ✓ Dataset loaded.
# Trying search strategy "content|service_template_id|service_template_id|content|1":
# ℹ 2 error occurrences found. They are used to create a intersection of all time windows before the error.
# ℹ 12 values in intersection of time windows found.
# ℹ 94 error occurrences found. They are used to mark the time windows that are skipped in the uniqueness check for root cause candidates.
# ✓ 2 lines added to root cause.
#
# Results:
#
# Line: 887806
# Timestamp: 2020-12-02 14:39:00.022000
# Service: WificondControl
# Template: Noise: <:NUM:>, Snr: <:NUM:>, Chload: <:NUM:>, rssi: <:NUM:>, txBitrate: <:NUM:>, rxBitrate: <:NUM:>, frequency: <:NUM:>, UlDelay: <:NUM:>, currentTxBytes: <:*:> currentTxPackets: <:NUM:>, currentTxFailed: <:NUM:>, currentRxBytes: <:*:> currentRxPackets: <:NUM:>
# Content: Noise: -100, Snr: 24, Chload: 162, rssi: -33, txBitrate: 866, rxBitrate: 780, frequency: 5745, UlDelay: 0, currentTxBytes: 482564114, currentTxPackets: 385319, currentTxFailed: 0, currentRxBytes: 76023072, currentRxPackets: 169030
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|0
#
# Line: 889545
# Timestamp: 2020-12-02 14:39:01.857000
# Service: wpa_supplicant
# Template: Notifying <:*:> <:*:> to hidl control: <:NUM:>
# Content: Notifying disconnect reason to hidl control: -3
# Found with strategies:
# - content|service_template_id|service_template_id|content|1|1
#
# Line: 889546
# Timestamp: 2020-12-02 14:39:01.857000
# Service: wpa_supplicant
# Template: <:*:> Disconnect event - remove keys
# Content: p2p-p2p0-5: Disconnect event - remove keys

# %% [markdown]
# ❌ The root cause can not be derived from the returned result.
